# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset
file_path = "/home/linar/Desktop/ML/Clases/i302/Proyecto_Final/Default/Data/OFFICIAL/finanzas_test.xlsx"
df = pd.read_excel(file_path)
# Out:
# /home/linar/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
df.head()
# Out:
#       ID  LIMITE_CREDITO  GENERO  EDUCACION  ESTADO_CIVIL  EDAD  \
# 0  21013          6200.0       1          3             2    43
# 1  12484         11160.0       2          1             2    28
# 2   5006          2790.0       2          3             0    24
# 3  17317          1550.0       2          3             2    39
# 4  28164          4960.0       2          3             1    41
#
#    ESTADO_PAGO_1  ESTADO_PAGO_2  ESTADO_PAGO_3  ESTADO_PAGO_4  ...  \
# 0              3              2              2              2  ...
# 1              0             -1             -1             -1  ...
# 2             -2             -2             -2             -1  ...
# 3              2              2              0              0  ...
# 4              1              2              2              2  ...
#
#    MONTO_FACTURA_4  MONTO_FACTURA_5  MONTO_FACTURA_6  MONTO_PAGO_1  \
# 0         77.95000         77.85000         77.65000       0.00000
# ...

# %%
df.to_excel("/home/linar/Desktop/ML/Clases/i302/Proyecto_Final/Default/Data/OFFICIAL/TEST_SET_TO_UPLOAD/finanzas_test+target.xlsx", index=False)

# %%
filtered_df = df.drop(columns="DEFAULT_SIGUIENTE_MES")
filtered_df.head()
# Out:
#       ID  LIMITE_CREDITO  GENERO  EDUCACION  ESTADO_CIVIL  EDAD  \
# 0  21013          6200.0       1          3             2    43
# 1  12484         11160.0       2          1             2    28
# 2   5006          2790.0       2          3             0    24
# 3  17317          1550.0       2          3             2    39
# 4  28164          4960.0       2          3             1    41
#
#    ESTADO_PAGO_1  ESTADO_PAGO_2  ESTADO_PAGO_3  ESTADO_PAGO_4  ...  \
# 0              3              2              2              2  ...
# 1              0             -1             -1             -1  ...
# 2             -2             -2             -2             -1  ...
# 3              2              2              0              0  ...
# 4              1              2              2              2  ...
#
#    MONTO_FACTURA_3  MONTO_FACTURA_4  MONTO_FACTURA_5  MONTO_FACTURA_6  \
# 0         78.35000         77.95000         77.85000         77.65000
# ...

# %%
filtered_df.to_excel("/home/linar/Desktop/ML/Clases/i302/Proyecto_Final/Default/Data/OFFICIAL/TEST_SET_TO_UPLOAD/finanzas_test.xlsx", index=False)
